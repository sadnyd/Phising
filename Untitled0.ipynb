# %% [markdown]
# <a href="https://colab.research.google.com/github/sadnyd/Phising/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!/bin/bash
# !kaggle datasets download shashwatwork/phishing-dataset-for-machine-learning
# Out:
# Dataset URL: https://www.kaggle.com/datasets/shashwatwork/phishing-dataset-for-machine-learning
# License(s): Attribution 4.0 International (CC BY 4.0)
# ...
#   0% 0.00/234k [00:00<?, ?B/s]
# 100% 234k/234k [00:00<00:00, 64.3MB/s]

# %%
# !unzip phising.zip
# Out:
# Archive:  phising.zip
#   inflating: Phishing_Legitimate_full.csv

# %%
import pandas as pd

# %%
df=pd.read_csv('./Phishing_Legitimate_full.csv')

# %%
df.head()
# Out:
#    id  NumDots  SubdomainLevel  PathLevel  UrlLength  NumDash  \
# 0   1        3               1          5         72        0
# 1   2        3               1          3        144        0
# 2   3        3               1          2         58        0
# 3   4        3               1          6         79        1
# 4   5        3               0          4         46        0
#
#    NumDashInHostname  AtSymbol  TildeSymbol  NumUnderscore  ...  \
# 0                  0         0            0              0  ...
# 1                  0         0            0              2  ...
# 2                  0         0            0              0  ...
# 3                  0         0            0              0  ...
# 4                  0         0            0              0  ...
#
#    IframeOrFrame  MissingTitle  ImagesOnlyInForm  SubdomainLevelRT  \
# 0              0             0                 1                 1
# 1              0             0                 0                 1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  10000 non-null  int64
#  1   NumDots                             10000 non-null  int64
#  2   SubdomainLevel                      10000 non-null  int64
#  3   PathLevel                           10000 non-null  int64
#  4   UrlLength                           10000 non-null  int64
#  5   NumDash                             10000 non-null  int64
#  6   NumDashInHostname                   10000 non-null  int64
#  7   AtSymbol                            10000 non-null  int64
#  8   TildeSymbol                         10000 non-null  int64
#  9   NumUnderscore                       10000 non-null  int64
#  10  NumPercent                          10000 non-null  int64
# ...

# %%
df.describe()
# Out:
#                 id       NumDots  SubdomainLevel     PathLevel     UrlLength  \
# count  10000.00000  10000.000000    10000.000000  10000.000000  10000.000000
# mean    5000.50000      2.445100        0.586800      3.300300     70.264100
# std     2886.89568      1.346836        0.751214      1.863241     33.369877
# min        1.00000      1.000000        0.000000      0.000000     12.000000
# 25%     2500.75000      2.000000        0.000000      2.000000     48.000000
# 50%     5000.50000      2.000000        1.000000      3.000000     62.000000
# 75%     7500.25000      3.000000        1.000000      4.000000     84.000000
# max    10000.00000     21.000000       14.000000     18.000000    253.000000
#
#             NumDash  NumDashInHostname      AtSymbol   TildeSymbol  \
# count  10000.000000       10000.000000  10000.000000  10000.000000
# mean       1.818000           0.138900      0.000300      0.013100
# std        3.106258           0.545744      0.017319      0.113709
# ...

# %%
df.isnull().sum()
# Out:
# id                                    0
# NumDots                               0
# SubdomainLevel                        0
# PathLevel                             0
# UrlLength                             0
# NumDash                               0
# NumDashInHostname                     0
# AtSymbol                              0
# TildeSymbol                           0
# NumUnderscore                         0
# NumPercent                            0
# NumQueryComponents                    0
# NumAmpersand                          0
# NumHash                               0
# NumNumericChars                       0
# NoHttps                               0
# RandomString                          0
# IpAddress                             0
# DomainInSubdomains                    0
# DomainInPaths                         0
# HttpsInHostname                       0
# HostnameLength                        0
# PathLength                            0
# ...

# %%
df.dropna()
# Out:
#          id  NumDots  SubdomainLevel  PathLevel  UrlLength  NumDash  \
# 0         1        3               1          5         72        0
# 1         2        3               1          3        144        0
# 2         3        3               1          2         58        0
# 3         4        3               1          6         79        1
# 4         5        3               0          4         46        0
# ...     ...      ...             ...        ...        ...      ...
# 9995   9996        3               1          1         50        0
# 9996   9997        2               1          4         59        1
# 9997   9998        2               1          4         57        0
# 9998   9999        3               1          1         49        0
# 9999  10000        3               1          2         52        3
#
#       NumDashInHostname  AtSymbol  TildeSymbol  NumUnderscore  ...  \
# 0                     0         0            0              0  ...
# ...

# %%
X=df.drop(columns=['CLASS_LABEL'])

# %%
X.head()
# Out:
#    id  NumDots  SubdomainLevel  PathLevel  UrlLength  NumDash  \
# 0   1        3               1          5         72        0
# 1   2        3               1          3        144        0
# 2   3        3               1          2         58        0
# 3   4        3               1          6         79        1
# 4   5        3               0          4         46        0
#
#    NumDashInHostname  AtSymbol  TildeSymbol  NumUnderscore  ...  \
# 0                  0         0            0              0  ...
# 1                  0         0            0              2  ...
# 2                  0         0            0              0  ...
# 3                  0         0            0              0  ...
# 4                  0         0            0              0  ...
#
#    SubmitInfoToEmail  IframeOrFrame  MissingTitle  ImagesOnlyInForm  \
# 0                  0              0             0                 1
# ...

# %%
y=df['CLASS_LABEL']

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: CLASS_LABEL, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, y_train,y_test= train_test_split(X,y,test_size=0.3,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model=RandomForestClassifier(random_state=42)
model
# Out:
# RandomForestClassifier(random_state=42)

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred=model.predict(X_test)

# %%
pd.DataFrame(y_pred).head()
# Out:
#    0
# 0  0
# 1  1
# 2  1
# 3  1
# 4  1

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
accu=accuracy_score(y_pred, y_test)
report=classification_report(y_pred, y_test)

# %%
accu
# Out:
# 1.0

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1463
#            1       1.00      1.00      1.00      1537
#
#     accuracy                           1.00      3000
#    macro avg       1.00      1.00      1.00      3000
# weighted avg       1.00      1.00      1.00      3000

# %%
from sklearn.linear_model import LogisticRegression

# %%
model2=LogisticRegression()

# %%
model2.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred2=model2.predict(X_test)

# %%
accu2=accuracy_score(y_pred2,y_test)
report2=classification_report(y_pred2,y_test)

# %%
accu2
# Out:
# 0.9763333333333334

# %%
print(report2)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98      1478
#            1       0.97      0.98      0.98      1522
#
#     accuracy                           0.98      3000
#    macro avg       0.98      0.98      0.98      3000
# weighted avg       0.98      0.98      0.98      3000

# %%
import pickle

# %%
pickle.dump(model,open('RF.pkl','wb'))

# %%
# !pwd
# Out:
# /content

# %%
pklModel= pickle.load(open('RF.pkl', 'rb'))

# %%
data=X.iloc[1:2]

# %%
data
# Out:
#    id  NumDots  SubdomainLevel  PathLevel  UrlLength  NumDash  \
# 1   2        3               1          3        144        0
#
#    NumDashInHostname  AtSymbol  TildeSymbol  NumUnderscore  ...  \
# 1                  0         0            0              2  ...
#
#    SubmitInfoToEmail  IframeOrFrame  MissingTitle  ImagesOnlyInForm  \
# 1                  0              0             0                 0
#
#    SubdomainLevelRT  UrlLengthRT  PctExtResourceUrlsRT  \
# 1                 1           -1                     1
#
#    AbnormalExtFormActionR  ExtMetaScriptLinkRT  \
# 1                       1                    1
#
#    PctExtNullSelfRedirectHyperlinksRT
# 1                                   1
#
# [1 rows x 49 columns]

# %%
y_pred=pklModel.predict(data)

# %%
y_pred
# Out:
# array([1])

# %%
y.iloc[1:2]
# Out:
# 1    1
# Name: CLASS_LABEL, dtype: int64
